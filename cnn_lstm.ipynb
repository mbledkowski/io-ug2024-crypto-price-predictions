# %% [markdown]
# https://arxiv.org/pdf/2309.11400
# https://arxiv.org/pdf/2411.05790
#
# TLDR LSTM is good enough

# %%
import numpy as np
import torch
import random
import os

def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
seed_everything(seed=420)

# %%
# %run load_data.ipynb
# Out:
#                        open   close    high     low     volume
# 2013-04-01 00:07:00   93.25   93.30   93.30   93.25  93.300000
# 2013-04-01 00:08:00  100.00  100.00  100.00  100.00  93.300000
# 2013-04-01 00:09:00   93.30   93.30   93.30   93.30  33.676862
# 2013-04-01 00:10:00   93.30   93.30   93.30   93.30   0.000000
# 2013-04-01 00:11:00   93.35   93.47   93.47   93.35  20.000000
#                         open    close     high      low    volume
# 2023-10-08 09:24:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:25:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:26:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:27:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:28:00  27912.0  27912.0  27912.0  27912.0  0.000442
#                        open   close    high     low    volume
# 2013-04-01 00:07:00   93.25   93.30   93.30   93.25  2.502149
# 2013-04-01 00:08:00  100.00  100.00  100.00  100.00  2.502149
# 2013-04-01 00:09:00   93.30   93.30   93.30   93.30  1.758977
# 2013-04-01 00:10:00   93.30   93.30   93.30   93.30 -0.875289
# 2013-04-01 00:11:00   93.35   93.47   93.47   93.35  1.386391 open      0.010000
# close     1.060000
# high      1.060000
# low       0.010000
# volume   -0.875289
# dtype: float64 open      68925.000000
# close     68925.000000
# high      68958.000000
# low       68734.000000
# volume        5.725743
# dtype: float64
# (22132168,)
# 11.14126740407234 0.009950330853168092 8.135346188400915 1.9180121525920217
# 68925.0 68925.0 68958.0 68734.0

# %%
from torch.utils.data import DataLoader, Dataset
import torch

# Convert DataFrame to numpy array
data = df_norm.values

# Create sequences and targets
def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        target = data[i + seq_length]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Parameters
seq_length = 64  # Length of each sequence

# Create sequences and targets
sequences, targets = create_sequences(data, seq_length)

# Sequential split
train_size = int(len(sequences) * 0.8)  # 80% for training, 20% for testing
X_train, X_test = sequences[:train_size], sequences[train_size:]
y_train, y_test = targets[:train_size], targets[train_size:]

# Custom Dataset
class TimeSeriesDataset(Dataset):
    def __init__(self, sequences, targets):
        self.sequences = torch.tensor(sequences, dtype=torch.float32)
        self.targets = torch.tensor(targets, dtype=torch.float32)

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        return self.sequences[idx], self.targets[idx]

# Create Datasets
train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

batch_size = 64

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size, shuffle=False)

print(X_train[0])
print()
print(y_train[0])

print(len(sequences), len(targets))
print(len(train_dataset), len(test_dataset))
print(sequences.shape, targets.shape)
# Out:
# [[-1.87141273 -1.87113936 -1.87131296 -1.87123868  2.50214939]
#  [-1.83534954 -1.83535263 -1.83552686 -1.83517486  2.50214939]
#  [-1.87113621 -1.87113936 -1.87131296 -1.87096215  1.75897727]
#  [-1.87113621 -1.87113936 -1.87131296 -1.87096215 -0.87528894]
#  [-1.87085984 -1.87020029 -1.87037391 -1.87068578  1.38639133]
#  [-1.87019715 -1.87020029 -1.87037391 -1.87002308 -0.05382818]
#  [-1.87263109 -1.8726343  -1.87280782 -1.87245712  0.45394314]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87255358 -1.87255673 -1.87273031 -1.87237955  1.06852283]
#  [-1.87255358 -1.87255673 -1.87273031 -1.87237955 -0.87528894]
#  [-1.8708599  -1.87086299 -1.87103659 -1.87068583  0.45575299]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87168945 -1.87086299 -1.87103659 -1.8715154   1.88340732]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87141273 -1.87113936 -1.87131296 -1.87123868  1.32368033]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912  1.46393302]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.78095408]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069403 -1.87069729 -1.87087079 -1.87052008  0.22688189]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008  0.46913836]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]]
#
# [-1.87014191 -1.87069729 -1.87031867 -1.87052008  0.3177423 ]
# 5532978 5532978
# 4426382 1106596
# (5532978, 64, 5) (5532978, 5)

# %% [markdown]
# # Create RNN Model

# %%
import torch.nn as nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Create RNN Model
class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, layer_dim, output_dim, conv1=16, conv2=8):
        super(LSTMModel, self).__init__()

        self.input_dim = input_dim
        # Number of hidden dimensions
        self.hidden_dim = hidden_dim

        # Number of hidden layers
        self.layer_dim = layer_dim

        self.conv1 = conv1
        self.conv2 = conv2

        self.sigma = nn.Sigmoid()

        self.conv1 = nn.Conv2d(1, conv1, (3,3), padding=1)

        self.selu1 = nn.SELU()
        
        self.conv2 = nn.Conv2d(conv1, conv2, (3,3), padding=1)

        self.selu2 = nn.SELU()
        
        self.conv3 = nn.Conv2d(conv2, 1, (3,3), padding=1)

        self.selu3 = nn.SELU()
        
        # RNN
        self.lstm = nn.LSTM(input_dim, hidden_dim, layer_dim, batch_first=True)

        # Readout layer
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        # Initialize hidden state with zeros
        h0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).to(device)
        c0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).to(device)

        inp = self.sigma(x)
        inp = inp.unsqueeze(1)
        # print(inp.shape)
        conv1 = self.selu1(self.conv1(inp))
        # print(conv1.shape)
        conv2 = self.selu2(self.conv2(conv1))
        # print(conv2.shape)
        conv3 = self.selu3(self.conv3(conv2))
        conv3 = conv3.squeeze()
        # print(conv3.shape)
        out, (hn, cn) = self.lstm(conv3, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# # Plot the predictions

# %%
def getPredictions(model):
    # Ensure the model is in evaluation mode
    model.eval()

    # Prepare data for prediction
    entire_loader = DataLoader(TimeSeriesDataset(sequences, targets), batch_size, shuffle=False)

    # Generate predictions
    predictions = []

    with torch.no_grad():
        for x, _ in entire_loader:
            x = x.to(device)
            pred = model(x)
            predictions.append(pred.cpu().numpy())

    predictions = np.concatenate(predictions)
    
    return predictions

# %%
import matplotlib.pyplot as plt

def getPredPlot(model):
    predictions = getPredictions(model)
    # Convert predictions to a DataFrame
    pred_df = pd.DataFrame(predictions, columns=['open', 'close', 'high', 'low', 'volume'])

    # Align the index with the original data
    pred_df.index = df_norm.index[seq_length:]

    print(pred_df.head(5))
    print(df_norm.head(5))

    # Create a DataFrame for plotting
    plot_df = df_norm[seq_length:][['open', 'close', 'high', 'low']].copy()
    plot_df['predicted_close'] = pred_df['close'].copy()

    print(plot_df.head(5))

    # Plot the actual vs predicted close prices using matplotlib
    plt.figure(figsize=(14, 7))
    plt.plot(plot_df.index, plot_df['close'], label='Actual Close', color='blue')
    plt.plot(plot_df.index, plot_df['predicted_close'], label='Predicted Close', color='red', linestyle='--')
    plt.title('Actual vs Predicted Close Prices')
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %% [markdown]
# # Train the model

# %%
import math
# from torchsummary import summary

hidden_dim = 32
layer_dim = 8
model = LSTMModel(input_dim=5, hidden_dim=hidden_dim, layer_dim=layer_dim, output_dim=5).to(device)

# summary(model,(seq_length,5))

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

epochs = 3

for epoch in range(epochs):
    model.train()
    for i, (x, y) in enumerate(train_loader):
        x = x.to(device)
        y = y.to(device)
        
        optimizer.zero_grad()
        
        y_pred = model(x)
        loss = criterion(y_pred, y)
        
        loss.backward()
        optimizer.step()

        # Print status every 2000 iterations
        if (i + 1) % math.floor(len(train_loader)/30) == 0:
            print(f'Epoch [{epoch+1}/{epochs}], Iteration [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')

            if (i+1) % (math.floor(len(train_loader)/30) * 3) == 0:
                # Evaluate on test data
                model.eval()  # Set the model to evaluation mode
                test_loss = 0.0
                test_acc = 0.0  # To accumulate accuracy scores
                total_samples = 0     # To keep track of total samples
                
                with torch.no_grad():  # Disable gradient calculation
                    for x_test, y_test in test_loader:
                        x_test = x_test.to(device)
                        y_test = y_test.to(device)

                        y_test_pred = model(x_test)
                        test_loss += criterion(y_test_pred, y_test).item()

                        if (i+1) % (math.floor(len(train_loader)/30) * 6) == 0:
                            x_test = x_test.cpu().numpy()
    
                            # Assuming the last feature in x_test is 'close'
                            # Adjust the feature index accordingly
                            prev_np = x_test[:, -1, 1]  # Shape: (batch_size,)
    
                            pred_np = y_test_pred.squeeze().cpu().numpy()[:, 1]
                            actual_np = y_test.cpu().numpy()[:,1]
                            
                            # Initialize accuracy for this batch
                            batch_accuracy = 0.0
    
                            for pred, actual, prev in zip(pred_np, actual_np, prev_np):
        
                                # if (actual > prev and pred > prev) or (actual < prev and pred < prev) or (actual == prev and pred == prev):
                                #     batch_accuracy += 1.0
                                # elif (actual != prev and pred == prev) or (actual == prev and pred != prev):
                                #     batch_accuracy += 0.5
                                
                                if (actual > prev and pred > prev) or (actual <= prev and pred <= prev):
                                    batch_accuracy += 1.0
                                else:
                                    batch_accuracy += 0.0
                                
                                total_samples += 1
                                
                            test_acc += batch_accuracy

                test_loss /= len(test_loader)  # Average test loss
                print(f'Test Loss: {test_loss:.4f}')
                if (test_acc != 0):
                    test_acc /=  (total_samples / 100)  # Percentage
                    print(f'Test Accuracy: {test_acc:.2f}%')
                
                model.train()  # Set the model back to training mode
    getPredPlot(model)
# Out:
# Epoch [1/3], Iteration [2305/69163], Loss: 0.2799
# Epoch [1/3], Iteration [4610/69163], Loss: 0.1545
# Epoch [1/3], Iteration [6915/69163], Loss: 0.0925
# Test Loss: 0.0653
# Epoch [1/3], Iteration [9220/69163], Loss: 0.0749
# Epoch [1/3], Iteration [11525/69163], Loss: 0.1245
# Epoch [1/3], Iteration [13830/69163], Loss: 0.1202
# Test Loss: 0.0488
# Test Accuracy: 46.03%
# Epoch [1/3], Iteration [16135/69163], Loss: 0.0895
# Epoch [1/3], Iteration [18440/69163], Loss: 0.1643
# Epoch [1/3], Iteration [20745/69163], Loss: 0.1184
# Test Loss: 0.0554
# Epoch [1/3], Iteration [23050/69163], Loss: 0.1048
# Epoch [1/3], Iteration [25355/69163], Loss: 0.1276
# Epoch [1/3], Iteration [27660/69163], Loss: 0.1153
# Test Loss: 0.0457
# Test Accuracy: 44.46%
# Epoch [1/3], Iteration [29965/69163], Loss: 0.1736
# Epoch [1/3], Iteration [32270/69163], Loss: 0.1429
# Epoch [1/3], Iteration [34575/69163], Loss: 0.1053
# Test Loss: 0.0459
# Epoch [1/3], Iteration [36880/69163], Loss: 0.0732
# Epoch [1/3], Iteration [39185/69163], Loss: 0.0741
# Epoch [1/3], Iteration [41490/69163], Loss: 0.1162
# Test Loss: 0.0485
# Test Accuracy: 42.88%
# Epoch [1/3], Iteration [43795/69163], Loss: 0.0975
# Epoch [1/3], Iteration [46100/69163], Loss: 0.1152
# Epoch [1/3], Iteration [48405/69163], Loss: 0.0805
# Test Loss: 0.0479
# Epoch [1/3], Iteration [50710/69163], Loss: 0.1049
# Epoch [1/3], Iteration [53015/69163], Loss: 0.1230
# Epoch [1/3], Iteration [55320/69163], Loss: 0.1087
# Test Loss: 0.0506
# Test Accuracy: 43.00%
# Epoch [1/3], Iteration [57625/69163], Loss: 0.1471
# Epoch [1/3], Iteration [59930/69163], Loss: 0.1316
# Epoch [1/3], Iteration [62235/69163], Loss: 0.1266
# Test Loss: 0.0464
# Epoch [1/3], Iteration [64540/69163], Loss: 0.0920
# Epoch [1/3], Iteration [66845/69163], Loss: 0.1377
# Epoch [1/3], Iteration [69150/69163], Loss: 0.1616
# Test Loss: 0.0471
# Test Accuracy: 44.58%
#                          open     close      high       low    volume
# 2013-04-01 01:11:00 -1.838518 -1.840046 -1.839485 -1.839889 -0.610790
# 2013-04-01 01:12:00 -1.854722 -1.856924 -1.856210 -1.856747 -0.452548
# 2013-04-01 01:13:00 -1.851506 -1.852101 -1.851857 -1.852235 -0.334226
# 2013-04-01 01:14:00 -1.856245 -1.857819 -1.857184 -1.857877 -0.432624
# 2013-04-01 01:15:00 -1.863613 -1.865005 -1.864375 -1.865041 -0.562082
#                          open     close      high       low    volume
# 2013-04-01 00:07:00 -1.871413 -1.871139 -1.871313 -1.871239  2.502149
# 2013-04-01 00:08:00 -1.835350 -1.835353 -1.835527 -1.835175  2.502149
# 2013-04-01 00:09:00 -1.871136 -1.871139 -1.871313 -1.870962  1.758977
# 2013-04-01 00:10:00 -1.871136 -1.871139 -1.871313 -1.870962 -0.875289
# 2013-04-01 00:11:00 -1.870860 -1.870200 -1.870374 -1.870686  1.386391
#                          open     close      high       low  predicted_close
# 2013-04-01 01:11:00 -1.870142 -1.870697 -1.870319 -1.870520        -1.840046
# 2013-04-01 01:12:00 -1.870142 -1.870101 -1.870275 -1.871515        -1.856924
# 2013-04-01 01:13:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.852101
# 2013-04-01 01:14:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.857819
# 2013-04-01 01:15:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.865005
# Epoch [2/3], Iteration [2305/69163], Loss: 0.0803
# Epoch [2/3], Iteration [4610/69163], Loss: 0.0933
# Epoch [2/3], Iteration [6915/69163], Loss: 0.0702
# Test Loss: 0.0504
# Epoch [2/3], Iteration [9220/69163], Loss: 0.0894
# Epoch [2/3], Iteration [11525/69163], Loss: 0.0769
# Epoch [2/3], Iteration [13830/69163], Loss: 0.1108
# Test Loss: 0.0473
# Test Accuracy: 56.15%
# Epoch [2/3], Iteration [16135/69163], Loss: 0.1057
# Epoch [2/3], Iteration [18440/69163], Loss: 0.0928
# Epoch [2/3], Iteration [20745/69163], Loss: 0.1364
# Test Loss: 0.0545
# Epoch [2/3], Iteration [23050/69163], Loss: 0.1098
# Epoch [2/3], Iteration [25355/69163], Loss: 0.0924
# Epoch [2/3], Iteration [27660/69163], Loss: 0.0768
# Test Loss: 0.0480
# Test Accuracy: 43.49%
# Epoch [2/3], Iteration [29965/69163], Loss: 0.1062
# Epoch [2/3], Iteration [32270/69163], Loss: 0.1218
# Epoch [2/3], Iteration [34575/69163], Loss: 0.1001
# Test Loss: 0.0452
# Epoch [2/3], Iteration [36880/69163], Loss: 0.0751
# Epoch [2/3], Iteration [39185/69163], Loss: 0.0774
# Epoch [2/3], Iteration [41490/69163], Loss: 0.0758
# Test Loss: 0.0452
# Test Accuracy: 43.68%
# Epoch [2/3], Iteration [43795/69163], Loss: 0.0939
# Epoch [2/3], Iteration [46100/69163], Loss: 0.1065
# Epoch [2/3], Iteration [48405/69163], Loss: 0.0692
# Test Loss: 0.0461
# Epoch [2/3], Iteration [50710/69163], Loss: 0.1385
# Epoch [2/3], Iteration [53015/69163], Loss: 0.0718
# Epoch [2/3], Iteration [55320/69163], Loss: 0.1119
# Test Loss: 0.0464
# Test Accuracy: 43.09%
# Epoch [2/3], Iteration [57625/69163], Loss: 0.1239
# Epoch [2/3], Iteration [59930/69163], Loss: 0.0976
# Epoch [2/3], Iteration [62235/69163], Loss: 0.1051
# Test Loss: 0.0463
# Epoch [2/3], Iteration [64540/69163], Loss: 0.0944
# Epoch [2/3], Iteration [66845/69163], Loss: 0.1064
# Epoch [2/3], Iteration [69150/69163], Loss: 0.0708
# Test Loss: 0.0452
# Test Accuracy: 54.26%
#                          open     close      high       low    volume
# 2013-04-01 01:11:00 -1.847062 -1.846987 -1.847041 -1.847015 -0.636393
# 2013-04-01 01:12:00 -1.858961 -1.858856 -1.858839 -1.858995 -0.379059
# 2013-04-01 01:13:00 -1.858947 -1.858798 -1.858695 -1.859047 -0.214952
# 2013-04-01 01:14:00 -1.880159 -1.880076 -1.880036 -1.880219 -0.344965
# 2013-04-01 01:15:00 -1.885299 -1.885244 -1.885249 -1.885316 -0.552728
#                          open     close      high       low    volume
# 2013-04-01 00:07:00 -1.871413 -1.871139 -1.871313 -1.871239  2.502149
# 2013-04-01 00:08:00 -1.835350 -1.835353 -1.835527 -1.835175  2.502149
# 2013-04-01 00:09:00 -1.871136 -1.871139 -1.871313 -1.870962  1.758977
# 2013-04-01 00:10:00 -1.871136 -1.871139 -1.871313 -1.870962 -0.875289
# 2013-04-01 00:11:00 -1.870860 -1.870200 -1.870374 -1.870686  1.386391
#                          open     close      high       low  predicted_close
# 2013-04-01 01:11:00 -1.870142 -1.870697 -1.870319 -1.870520        -1.846987
# 2013-04-01 01:12:00 -1.870142 -1.870101 -1.870275 -1.871515        -1.858856
# 2013-04-01 01:13:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.858798
# 2013-04-01 01:14:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.880076
# 2013-04-01 01:15:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.885244
# Epoch [3/3], Iteration [2305/69163], Loss: 0.0824
# Epoch [3/3], Iteration [4610/69163], Loss: 0.1003
# Epoch [3/3], Iteration [6915/69163], Loss: 0.1439
# Test Loss: 0.0462
# Epoch [3/3], Iteration [9220/69163], Loss: 0.0961
# Epoch [3/3], Iteration [11525/69163], Loss: 0.1072
# Epoch [3/3], Iteration [13830/69163], Loss: 0.1187
# Test Loss: 0.0454
# Test Accuracy: 43.24%
# Epoch [3/3], Iteration [16135/69163], Loss: 0.1293
# Epoch [3/3], Iteration [18440/69163], Loss: 0.0909
# Epoch [3/3], Iteration [20745/69163], Loss: 0.1549
# Test Loss: 0.0510
# Epoch [3/3], Iteration [23050/69163], Loss: 0.1138
# Epoch [3/3], Iteration [25355/69163], Loss: 0.0946
# Epoch [3/3], Iteration [27660/69163], Loss: 0.0937
# Test Loss: 0.0450
# Test Accuracy: 44.02%
# Epoch [3/3], Iteration [29965/69163], Loss: 0.0995
# Epoch [3/3], Iteration [32270/69163], Loss: 0.1020
# Epoch [3/3], Iteration [34575/69163], Loss: 0.0960
# Test Loss: 0.0478
# Epoch [3/3], Iteration [36880/69163], Loss: 0.1094
# Epoch [3/3], Iteration [39185/69163], Loss: 0.1023
# Epoch [3/3], Iteration [41490/69163], Loss: 0.1229
# Test Loss: 0.0466
# Test Accuracy: 42.99%
# Epoch [3/3], Iteration [43795/69163], Loss: 0.0759
# Epoch [3/3], Iteration [46100/69163], Loss: 0.0496
# Epoch [3/3], Iteration [48405/69163], Loss: 0.0967
# Test Loss: 0.0448
# Epoch [3/3], Iteration [50710/69163], Loss: 0.0935
# Epoch [3/3], Iteration [53015/69163], Loss: 0.0805
# Epoch [3/3], Iteration [55320/69163], Loss: 0.1040
# Test Loss: 0.0446
# Test Accuracy: 47.89%
# Epoch [3/3], Iteration [57625/69163], Loss: 0.1120
# Epoch [3/3], Iteration [59930/69163], Loss: 0.0911
# Epoch [3/3], Iteration [62235/69163], Loss: 0.0745
# Test Loss: 0.0490
# Epoch [3/3], Iteration [64540/69163], Loss: 0.1413
# Epoch [3/3], Iteration [66845/69163], Loss: 0.1036
# Epoch [3/3], Iteration [69150/69163], Loss: 0.0753
# Test Loss: 0.0453
# Test Accuracy: 43.56%
#                          open     close      high       low    volume
# 2013-04-01 01:11:00 -1.864322 -1.864853 -1.864738 -1.864442 -0.653208
# 2013-04-01 01:12:00 -1.877788 -1.878236 -1.877996 -1.878017 -0.412918
# 2013-04-01 01:13:00 -1.876990 -1.877430 -1.877096 -1.877302 -0.260241
# 2013-04-01 01:14:00 -1.883882 -1.884470 -1.884196 -1.884126 -0.406229
# 2013-04-01 01:15:00 -1.883712 -1.884303 -1.884095 -1.883900 -0.556244
#                          open     close      high       low    volume
# 2013-04-01 00:07:00 -1.871413 -1.871139 -1.871313 -1.871239  2.502149
# 2013-04-01 00:08:00 -1.835350 -1.835353 -1.835527 -1.835175  2.502149
# 2013-04-01 00:09:00 -1.871136 -1.871139 -1.871313 -1.870962  1.758977
# 2013-04-01 00:10:00 -1.871136 -1.871139 -1.871313 -1.870962 -0.875289
# 2013-04-01 00:11:00 -1.870860 -1.870200 -1.870374 -1.870686  1.386391
#                          open     close      high       low  predicted_close
# 2013-04-01 01:11:00 -1.870142 -1.870697 -1.870319 -1.870520        -1.864853
# 2013-04-01 01:12:00 -1.870142 -1.870101 -1.870275 -1.871515        -1.878236
# 2013-04-01 01:13:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.877430
# 2013-04-01 01:14:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.884470
# 2013-04-01 01:15:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.884303

# %%
# torch.cuda.memory._dump_snapshot("snapshot.pickle")

# %%
model.eval()
torch.save({"model_state_dict": model.cpu().state_dict()}, "models/cnn_lstm.model")
