# %%
# import torch
# torch.cuda.memory._record_memory_history()

# %%
import numpy as np
import torch
import random
import os

def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
seed_everything(seed=42)

# %%
# %run load_data.ipynb
# Out:
#                        open   close    high     low     volume
# 2013-04-01 00:07:00   93.25   93.30   93.30   93.25  93.300000
# 2013-04-01 00:08:00  100.00  100.00  100.00  100.00  93.300000
# 2013-04-01 00:09:00   93.30   93.30   93.30   93.30  33.676862
# 2013-04-01 00:10:00   93.30   93.30   93.30   93.30   0.000000
# 2013-04-01 00:11:00   93.35   93.47   93.47   93.35  20.000000
#                         open    close     high      low    volume
# 2023-10-08 09:24:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:25:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:26:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:27:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:28:00  27912.0  27912.0  27912.0  27912.0  0.000442
#                        open   close    high     low    volume
# 2013-04-01 00:07:00   93.25   93.30   93.30   93.25  2.502149
# 2013-04-01 00:08:00  100.00  100.00  100.00  100.00  2.502149
# 2013-04-01 00:09:00   93.30   93.30   93.30   93.30  1.758977
# 2013-04-01 00:10:00   93.30   93.30   93.30   93.30 -0.875289
# 2013-04-01 00:11:00   93.35   93.47   93.47   93.35  1.386391 open      0.010000
# close     1.060000
# high      1.060000
# low       0.010000
# volume   -0.875289
# dtype: float64 open      68925.000000
# close     68925.000000
# high      68958.000000
# low       68734.000000
# volume        5.725743
# dtype: float64
# (22132168,)
# 11.14126740407234 0.009950330853168092 8.135346188400915 1.9180121525920217
# 68925.0 68925.0 68958.0 68734.0

# %%
from torch.utils.data import DataLoader, Dataset
import torch

# Convert DataFrame to numpy array
data = df_norm.values

# Create sequences and targets
def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        target = data[i + seq_length]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Parameters
seq_length = 64  # Length of each sequence

# Create sequences and targets
sequences, targets = create_sequences(data, seq_length)

# Sequential split
train_size = int(len(sequences) * 0.8)  # 80% for training, 20% for testing
X_train, X_test = sequences[:train_size], sequences[train_size:]
y_train, y_test = targets[:train_size], targets[train_size:]

# Custom Dataset
class TimeSeriesDataset(Dataset):
    def __init__(self, sequences, targets):
        self.sequences = torch.tensor(sequences, dtype=torch.float32)
        self.targets = torch.tensor(targets, dtype=torch.float32)

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        return self.sequences[idx], self.targets[idx]

# Create Datasets
train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

batch_size = 64

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size, shuffle=False)

print(X_train[0])
print()
print(y_train[0])

print(len(sequences), len(targets))
print(len(train_dataset), len(test_dataset))
print(sequences.shape, targets.shape)
# Out:
# [[-1.87141273 -1.87113936 -1.87131296 -1.87123868  2.50214939]
#  [-1.83534954 -1.83535263 -1.83552686 -1.83517486  2.50214939]
#  [-1.87113621 -1.87113936 -1.87131296 -1.87096215  1.75897727]
#  [-1.87113621 -1.87113936 -1.87131296 -1.87096215 -0.87528894]
#  [-1.87085984 -1.87020029 -1.87037391 -1.87068578  1.38639133]
#  [-1.87019715 -1.87020029 -1.87037391 -1.87002308 -0.05382818]
#  [-1.87263109 -1.8726343  -1.87280782 -1.87245712  0.45394314]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87255358 -1.87255673 -1.87273031 -1.87237955  1.06852283]
#  [-1.87255358 -1.87255673 -1.87273031 -1.87237955 -0.87528894]
#  [-1.8708599  -1.87086299 -1.87103659 -1.87068583  0.45575299]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87168945 -1.87086299 -1.87103659 -1.8715154   1.88340732]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87141273 -1.87113936 -1.87131296 -1.87123868  1.32368033]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912  1.46393302]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.78095408]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069403 -1.87069729 -1.87087079 -1.87052008  0.22688189]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008  0.46913836]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]]
#
# [-1.87014191 -1.87069729 -1.87031867 -1.87052008  0.3177423 ]
# 5532978 5532978
# 4426382 1106596
# (5532978, 64, 5) (5532978, 5)

# %% [markdown]
# # Create RNN Model

# %%
import torch.nn as nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Create RNN Model
class RNNModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, layer_dim, output_dim):
        super(RNNModel, self).__init__()

        # Number of hidden dimensions
        self.hidden_dim = hidden_dim

        # Number of hidden layers
        self.layer_dim = layer_dim

        self.sigma = nn.Sigmoid()

        # RNN
        self.rnn = nn.RNN(input_dim, hidden_dim, layer_dim, batch_first=True)

        # Readout layer
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        # Initialize hidden state with zeros
        h0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).to(device)

        inp = self.sigma(x)
        out, hn = self.rnn(inp, h0)
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# # Plot the predictions

# %%
def getPredictions(model):
    # Ensure the model is in evaluation mode
    model.eval()

    # Prepare data for prediction
    entire_loader = DataLoader(TimeSeriesDataset(sequences, targets), batch_size, shuffle=False)

    # Generate predictions
    predictions = []

    with torch.no_grad():
        for x, _ in entire_loader:
            x = x.to(device)
            pred = model(x)
            predictions.append(pred.cpu().numpy())

    predictions = np.concatenate(predictions)
    
    return predictions

# %%
import matplotlib.pyplot as plt

def getPredPlot(model):
    predictions = getPredictions(model)
    # Convert predictions to a DataFrame
    pred_df = pd.DataFrame(predictions, columns=['open', 'close', 'high', 'low', 'volume'])

    # Align the index with the original data
    pred_df.index = df_norm.index[seq_length:]

    print(pred_df.head(5))
    print(df_norm.head(5))

    # Create a DataFrame for plotting
    plot_df = df_norm[seq_length:][['open', 'close', 'high', 'low']].copy()
    plot_df['predicted_close'] = pred_df['close'].copy()

    print(plot_df.head(5))

    # Plot the actual vs predicted close prices using matplotlib
    plt.figure(figsize=(14, 7))
    plt.plot(plot_df.index, plot_df['close'], label='Actual Close', color='blue')
    plt.plot(plot_df.index, plot_df['predicted_close'], label='Predicted Close', color='red', linestyle='--')
    plt.title('Actual vs Predicted Close Prices')
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %% [markdown]
# # Train the model

# %%
import math
# from torchsummary import summary

hidden_dim = 32
layer_dim = 8
model = RNNModel(input_dim=5, hidden_dim=hidden_dim, layer_dim=layer_dim, output_dim=5).to(device)

# summary(model,(seq_length,5))

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

epochs = 3

for epoch in range(epochs):
    model.train()
    for i, (x, y) in enumerate(train_loader):
        x = x.to(device)
        y = y.to(device)
        
        optimizer.zero_grad()
        
        y_pred = model(x)
        loss = criterion(y_pred, y)
        
        loss.backward()
        optimizer.step()

        # Print status every 2000 iterations
        if (i + 1) % math.floor(len(train_loader)/30) == 0:
            print(f'Epoch [{epoch+1}/{epochs}], Iteration [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')

            if (i+1) % (math.floor(len(train_loader)/30) * 3) == 0:
                # Evaluate on test data
                model.eval()  # Set the model to evaluation mode
                test_loss = 0.0
                test_acc = 0.0  # To accumulate accuracy scores
                total_samples = 0     # To keep track of total samples
                
                with torch.no_grad():  # Disable gradient calculation
                    for x_test, y_test in test_loader:
                        x_test = x_test.to(device)
                        y_test = y_test.to(device)

                        y_test_pred = model(x_test)
                        test_loss += criterion(y_test_pred, y_test).item()

                        if (i+1) % (math.floor(len(train_loader)/30) * 6) == 0:
                            x_test = x_test.cpu().numpy()
    
                            # Assuming the last feature in x_test is 'close'
                            # Adjust the feature index accordingly
                            prev_np = x_test[:, -1, 1]  # Shape: (batch_size,)
    
                            pred_np = y_test_pred.squeeze().cpu().numpy()[:, 1]
                            actual_np = y_test.cpu().numpy()[:,1]
                            
                            # Initialize accuracy for this batch
                            batch_accuracy = 0.0
    
                            for pred, actual, prev in zip(pred_np, actual_np, prev_np):
        
                                # if (actual > prev and pred > prev) or (actual < prev and pred < prev) or (actual == prev and pred == prev):
                                #     batch_accuracy += 1.0
                                # elif (actual != prev and pred == prev) or (actual == prev and pred != prev):
                                #     batch_accuracy += 0.5
                                
                                if (actual > prev and pred > prev) or (actual <= prev and pred <= prev):
                                    batch_accuracy += 1.0
                                else:
                                    batch_accuracy += 0.0
                                
                                total_samples += 1
                                
                            test_acc += batch_accuracy

                test_loss /= len(test_loader)  # Average test loss
                print(f'Test Loss: {test_loss:.4f}')
                if (test_acc != 0):
                    test_acc /=  (total_samples / 100)  # Percentage
                    print(f'Test Accuracy: {test_acc:.2f}%')
                
                model.train()  # Set the model back to training mode
    getPredPlot(model)
# Out:
# Epoch [1/3], Iteration [2305/69163], Loss: 0.1426
# Epoch [1/3], Iteration [4610/69163], Loss: 0.0998
# Epoch [1/3], Iteration [6915/69163], Loss: 0.1359
# Test Loss: 0.0500
# Epoch [1/3], Iteration [9220/69163], Loss: 0.1061
# Epoch [1/3], Iteration [11525/69163], Loss: 0.1289
# Epoch [1/3], Iteration [13830/69163], Loss: 0.1158
# Test Loss: 0.0674
# Test Accuracy: 57.10%
# Epoch [1/3], Iteration [16135/69163], Loss: 0.1080
# Epoch [1/3], Iteration [18440/69163], Loss: 0.1262
# Epoch [1/3], Iteration [20745/69163], Loss: 0.1163
# Test Loss: 0.0554
# Epoch [1/3], Iteration [23050/69163], Loss: 0.0929
# Epoch [1/3], Iteration [25355/69163], Loss: 0.0780
# Epoch [1/3], Iteration [27660/69163], Loss: 0.1216
# Test Loss: 0.0484
# Test Accuracy: 43.50%
# Epoch [1/3], Iteration [29965/69163], Loss: 0.1295
# Epoch [1/3], Iteration [32270/69163], Loss: 0.0942
# Epoch [1/3], Iteration [34575/69163], Loss: 0.0960
# Test Loss: 0.0671
# Epoch [1/3], Iteration [36880/69163], Loss: 0.0727
# Epoch [1/3], Iteration [39185/69163], Loss: 0.1224
# Epoch [1/3], Iteration [41490/69163], Loss: 0.1013
# Test Loss: 0.0630
# Test Accuracy: 43.15%
# Epoch [1/3], Iteration [43795/69163], Loss: 0.1061
# Epoch [1/3], Iteration [46100/69163], Loss: 0.1256
# Epoch [1/3], Iteration [48405/69163], Loss: 0.0743
# Test Loss: 0.0517
# Epoch [1/3], Iteration [50710/69163], Loss: 0.0869
# Epoch [1/3], Iteration [53015/69163], Loss: 0.0726
# Epoch [1/3], Iteration [55320/69163], Loss: 0.0817
# Test Loss: 0.0510
# Test Accuracy: 54.40%
# Epoch [1/3], Iteration [57625/69163], Loss: 0.1298
# Epoch [1/3], Iteration [59930/69163], Loss: 0.0921
# Epoch [1/3], Iteration [62235/69163], Loss: 0.0729
# Test Loss: 0.0542
# Epoch [1/3], Iteration [64540/69163], Loss: 0.0983
# Epoch [1/3], Iteration [66845/69163], Loss: 0.1554
# Epoch [1/3], Iteration [69150/69163], Loss: 0.0816
# Test Loss: 0.0483
# Test Accuracy: 44.33%
#                          open     close      high       low    volume
# 2013-04-01 01:11:00 -1.836969 -1.836861 -1.836690 -1.836793 -0.636361
# 2013-04-01 01:12:00 -1.828338 -1.828308 -1.828198 -1.828613 -0.316629
# 2013-04-01 01:13:00 -1.833714 -1.833689 -1.833945 -1.834154 -0.063891
# 2013-04-01 01:14:00 -1.853770 -1.853893 -1.855056 -1.854232 -0.265353
# 2013-04-01 01:15:00 -1.863685 -1.863604 -1.863726 -1.863515 -0.519756
#                          open     close      high       low    volume
# 2013-04-01 00:07:00 -1.871413 -1.871139 -1.871313 -1.871239  2.502149
# 2013-04-01 00:08:00 -1.835350 -1.835353 -1.835527 -1.835175  2.502149
# 2013-04-01 00:09:00 -1.871136 -1.871139 -1.871313 -1.870962  1.758977
# 2013-04-01 00:10:00 -1.871136 -1.871139 -1.871313 -1.870962 -0.875289
# 2013-04-01 00:11:00 -1.870860 -1.870200 -1.870374 -1.870686  1.386391
#                          open     close      high       low  predicted_close
# 2013-04-01 01:11:00 -1.870142 -1.870697 -1.870319 -1.870520        -1.836861
# 2013-04-01 01:12:00 -1.870142 -1.870101 -1.870275 -1.871515        -1.828308
# 2013-04-01 01:13:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.833689
# 2013-04-01 01:14:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.853893
# 2013-04-01 01:15:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.863604
# Epoch [2/3], Iteration [2305/69163], Loss: 0.1198
# Epoch [2/3], Iteration [4610/69163], Loss: 0.1186
# Epoch [2/3], Iteration [6915/69163], Loss: 0.1039
# Test Loss: 0.0503
# Epoch [2/3], Iteration [9220/69163], Loss: 0.1271
# Epoch [2/3], Iteration [11525/69163], Loss: 0.1114
# Epoch [2/3], Iteration [13830/69163], Loss: 0.1158
# Test Loss: 0.0597
# Test Accuracy: 43.16%
# Epoch [2/3], Iteration [16135/69163], Loss: 0.1102
# Epoch [2/3], Iteration [18440/69163], Loss: 0.0824
# Epoch [2/3], Iteration [20745/69163], Loss: 0.0983
# Test Loss: 0.0559
# Epoch [2/3], Iteration [23050/69163], Loss: 0.0794
# Epoch [2/3], Iteration [25355/69163], Loss: 0.1264
# Epoch [2/3], Iteration [27660/69163], Loss: 0.1205
# Test Loss: 0.0498
# Test Accuracy: 56.64%
# Epoch [2/3], Iteration [29965/69163], Loss: 0.1290
# Epoch [2/3], Iteration [32270/69163], Loss: 0.1521
# Epoch [2/3], Iteration [34575/69163], Loss: 0.0804
# Test Loss: 0.0506
# Epoch [2/3], Iteration [36880/69163], Loss: 0.1042
# Epoch [2/3], Iteration [39185/69163], Loss: 0.1317
# Epoch [2/3], Iteration [41490/69163], Loss: 0.1178
# Test Loss: 0.0512
# Test Accuracy: 57.13%
# Epoch [2/3], Iteration [43795/69163], Loss: 0.0632
# Epoch [2/3], Iteration [46100/69163], Loss: 0.1251
# Epoch [2/3], Iteration [48405/69163], Loss: 0.0892
# Test Loss: 0.0540
# Epoch [2/3], Iteration [50710/69163], Loss: 0.1051
# Epoch [2/3], Iteration [53015/69163], Loss: 0.1306
# Epoch [2/3], Iteration [55320/69163], Loss: 0.1468
# Test Loss: 0.0519
# Test Accuracy: 51.66%
# Epoch [2/3], Iteration [57625/69163], Loss: 0.1395
# Epoch [2/3], Iteration [59930/69163], Loss: 0.0833
# Epoch [2/3], Iteration [62235/69163], Loss: 0.1526
# Test Loss: 0.0540
# Epoch [2/3], Iteration [64540/69163], Loss: 0.1062
# Epoch [2/3], Iteration [66845/69163], Loss: 0.0729
# Epoch [2/3], Iteration [69150/69163], Loss: 0.1052
# Test Loss: 0.0503
# Test Accuracy: 55.14%
#                          open     close      high       low    volume
# 2013-04-01 01:11:00 -1.859582 -1.859564 -1.859545 -1.859458 -0.647521
# 2013-04-01 01:12:00 -1.852649 -1.852567 -1.852540 -1.852692 -0.390358
# 2013-04-01 01:13:00 -1.853860 -1.853711 -1.853703 -1.854079 -0.126166
# 2013-04-01 01:14:00 -1.906054 -1.905943 -1.905927 -1.906174 -0.311772
# 2013-04-01 01:15:00 -1.898642 -1.898604 -1.898589 -1.898547 -0.603690
#                          open     close      high       low    volume
# 2013-04-01 00:07:00 -1.871413 -1.871139 -1.871313 -1.871239  2.502149
# 2013-04-01 00:08:00 -1.835350 -1.835353 -1.835527 -1.835175  2.502149
# 2013-04-01 00:09:00 -1.871136 -1.871139 -1.871313 -1.870962  1.758977
# 2013-04-01 00:10:00 -1.871136 -1.871139 -1.871313 -1.870962 -0.875289
# 2013-04-01 00:11:00 -1.870860 -1.870200 -1.870374 -1.870686  1.386391
#                          open     close      high       low  predicted_close
# 2013-04-01 01:11:00 -1.870142 -1.870697 -1.870319 -1.870520        -1.859564
# 2013-04-01 01:12:00 -1.870142 -1.870101 -1.870275 -1.871515        -1.852567
# 2013-04-01 01:13:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.853711
# 2013-04-01 01:14:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.905943
# 2013-04-01 01:15:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.898604
# Epoch [3/3], Iteration [2305/69163], Loss: 0.1166
# Epoch [3/3], Iteration [4610/69163], Loss: 0.0613
# Epoch [3/3], Iteration [6915/69163], Loss: 0.0817
# Test Loss: 0.0502
# Epoch [3/3], Iteration [9220/69163], Loss: 0.1297
# Epoch [3/3], Iteration [11525/69163], Loss: 0.0985
# Epoch [3/3], Iteration [13830/69163], Loss: 0.0773
# Test Loss: 0.0486
# Test Accuracy: 45.65%
# Epoch [3/3], Iteration [16135/69163], Loss: 0.0644
# Epoch [3/3], Iteration [18440/69163], Loss: 0.1331
# Epoch [3/3], Iteration [20745/69163], Loss: 0.1274
# Test Loss: 0.0504
# Epoch [3/3], Iteration [23050/69163], Loss: 0.1148
# Epoch [3/3], Iteration [25355/69163], Loss: 0.1251
# Epoch [3/3], Iteration [27660/69163], Loss: 0.1038
# Test Loss: 0.0546
# Test Accuracy: 43.44%
# Epoch [3/3], Iteration [29965/69163], Loss: 0.1748
# Epoch [3/3], Iteration [32270/69163], Loss: 0.1263
# Epoch [3/3], Iteration [34575/69163], Loss: 0.1523
# Test Loss: 0.0535
# Epoch [3/3], Iteration [36880/69163], Loss: 0.0889
# Epoch [3/3], Iteration [39185/69163], Loss: 0.0789
# Epoch [3/3], Iteration [41490/69163], Loss: 0.1194
# Test Loss: 0.0500
# Test Accuracy: 52.77%
# Epoch [3/3], Iteration [43795/69163], Loss: 0.0875
# Epoch [3/3], Iteration [46100/69163], Loss: 0.1069
# Epoch [3/3], Iteration [48405/69163], Loss: 0.1427
# Test Loss: 0.0569
# Epoch [3/3], Iteration [50710/69163], Loss: 0.0993
# Epoch [3/3], Iteration [53015/69163], Loss: 0.2023
# Epoch [3/3], Iteration [55320/69163], Loss: 0.0960
# Test Loss: 0.0560
# Test Accuracy: 51.62%
# Epoch [3/3], Iteration [57625/69163], Loss: 0.1082
# Epoch [3/3], Iteration [59930/69163], Loss: 0.1370
# Epoch [3/3], Iteration [62235/69163], Loss: 0.1307
# Test Loss: 0.0514
# Epoch [3/3], Iteration [64540/69163], Loss: 0.0662
# Epoch [3/3], Iteration [66845/69163], Loss: 0.1015
# Epoch [3/3], Iteration [69150/69163], Loss: 0.1120
# Test Loss: 0.0492
# Test Accuracy: 46.20%
#                          open     close      high       low    volume
# 2013-04-01 01:11:00 -1.873119 -1.873036 -1.873001 -1.872917 -0.667708
# 2013-04-01 01:12:00 -1.873506 -1.873480 -1.873454 -1.873438 -0.357028
# 2013-04-01 01:13:00 -1.875504 -1.875574 -1.875569 -1.875594 -0.092202
# 2013-04-01 01:14:00 -1.910649 -1.910690 -1.910746 -1.910671 -0.280642
# 2013-04-01 01:15:00 -1.919571 -1.919544 -1.919517 -1.919471 -0.515254
#                          open     close      high       low    volume
# 2013-04-01 00:07:00 -1.871413 -1.871139 -1.871313 -1.871239  2.502149
# 2013-04-01 00:08:00 -1.835350 -1.835353 -1.835527 -1.835175  2.502149
# 2013-04-01 00:09:00 -1.871136 -1.871139 -1.871313 -1.870962  1.758977
# 2013-04-01 00:10:00 -1.871136 -1.871139 -1.871313 -1.870962 -0.875289
# 2013-04-01 00:11:00 -1.870860 -1.870200 -1.870374 -1.870686  1.386391
#                          open     close      high       low  predicted_close
# 2013-04-01 01:11:00 -1.870142 -1.870697 -1.870319 -1.870520        -1.873036
# 2013-04-01 01:12:00 -1.870142 -1.870101 -1.870275 -1.871515        -1.873480
# 2013-04-01 01:13:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.875574
# 2013-04-01 01:14:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.910690
# 2013-04-01 01:15:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.919544

# %%
# torch.cuda.memory._dump_snapshot("snapshot.pickle")

# %%
model.eval()
torch.save({"model_state_dict": model.cpu().state_dict()}, "models/rnn.model")
