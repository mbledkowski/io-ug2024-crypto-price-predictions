# %% [markdown]
# https://arxiv.org/pdf/2309.11400
# https://arxiv.org/pdf/2411.05790
#
# TLDR LSTM is good enough

# %%
import numpy as np
import torch
import random
import os

def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
seed_everything(seed=420)

# %%
# %run load_data.ipynb
# Out:
#                        open   close    high     low     volume
# 2013-04-01 00:07:00   93.25   93.30   93.30   93.25  93.300000
# 2013-04-01 00:08:00  100.00  100.00  100.00  100.00  93.300000
# 2013-04-01 00:09:00   93.30   93.30   93.30   93.30  33.676862
# 2013-04-01 00:10:00   93.30   93.30   93.30   93.30   0.000000
# 2013-04-01 00:11:00   93.35   93.47   93.47   93.35  20.000000
#                         open    close     high      low    volume
# 2023-10-08 09:24:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:25:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:26:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:27:00  27927.0  27927.0  27927.0  27927.0  0.000000
# 2023-10-08 09:28:00  27912.0  27912.0  27912.0  27912.0  0.000442
#                        open   close    high     low    volume
# 2013-04-01 00:07:00   93.25   93.30   93.30   93.25  2.502149
# 2013-04-01 00:08:00  100.00  100.00  100.00  100.00  2.502149
# 2013-04-01 00:09:00   93.30   93.30   93.30   93.30  1.758977
# 2013-04-01 00:10:00   93.30   93.30   93.30   93.30 -0.875289
# 2013-04-01 00:11:00   93.35   93.47   93.47   93.35  1.386391 open      0.010000
# close     1.060000
# high      1.060000
# low       0.010000
# volume   -0.875289
# dtype: float64 open      68925.000000
# close     68925.000000
# high      68958.000000
# low       68734.000000
# volume        5.725743
# dtype: float64
# (22132168,)
# 11.14126740407234 0.009950330853168092 8.135346188400915 1.9180121525920217
# 68925.0 68925.0 68958.0 68734.0

# %%
from torch.utils.data import DataLoader, Dataset
import torch

# Convert DataFrame to numpy array
data = df_norm.values

# Create sequences and targets
def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        target = data[i + seq_length]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Parameters
seq_length = 64  # Length of each sequence

# Create sequences and targets
sequences, targets = create_sequences(data, seq_length)

# Sequential split
train_size = int(len(sequences) * 0.8)  # 80% for training, 20% for testing
X_train, X_test = sequences[:train_size], sequences[train_size:]
y_train, y_test = targets[:train_size], targets[train_size:]

# Custom Dataset
class TimeSeriesDataset(Dataset):
    def __init__(self, sequences, targets):
        self.sequences = torch.tensor(sequences, dtype=torch.float32)
        self.targets = torch.tensor(targets, dtype=torch.float32)

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        return self.sequences[idx], self.targets[idx]

# Create Datasets
train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

batch_size = 64

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size, shuffle=False)

print(X_train[0])
print()
print(y_train[0])

print(len(sequences), len(targets))
print(len(train_dataset), len(test_dataset))
print(sequences.shape, targets.shape)
# Out:
# [[-1.87141273 -1.87113936 -1.87131296 -1.87123868  2.50214939]
#  [-1.83534954 -1.83535263 -1.83552686 -1.83517486  2.50214939]
#  [-1.87113621 -1.87113936 -1.87131296 -1.87096215  1.75897727]
#  [-1.87113621 -1.87113936 -1.87131296 -1.87096215 -0.87528894]
#  [-1.87085984 -1.87020029 -1.87037391 -1.87068578  1.38639133]
#  [-1.87019715 -1.87020029 -1.87037391 -1.87002308 -0.05382818]
#  [-1.87263109 -1.8726343  -1.87280782 -1.87245712  0.45394314]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87263115 -1.8726343  -1.87280787 -1.87245712 -0.87528894]
#  [-1.87255358 -1.87255673 -1.87273031 -1.87237955  1.06852283]
#  [-1.87255358 -1.87255673 -1.87273031 -1.87237955 -0.87528894]
#  [-1.8708599  -1.87086299 -1.87103659 -1.87068583  0.45575299]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87168945 -1.87086299 -1.87103659 -1.8715154   1.88340732]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87085984 -1.87086299 -1.87103659 -1.87068578 -0.87528894]
#  [-1.87141273 -1.87113936 -1.87131296 -1.87123868  1.32368033]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912  1.46393302]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87224316 -1.87224631 -1.87241989 -1.87206912 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.78095408]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069403 -1.87069729 -1.87087079 -1.87052008  0.22688189]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008  0.46913836]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]
#  [-1.87069414 -1.87069729 -1.8708709  -1.87052008 -0.87528894]]
#
# [-1.87014191 -1.87069729 -1.87031867 -1.87052008  0.3177423 ]
# 5532978 5532978
# 4426382 1106596
# (5532978, 64, 5) (5532978, 5)

# %% [markdown]
# # Create RNN Model

# %%
import torch.nn as nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Create RNN Model
class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, layer_dim, output_dim):
        super(LSTMModel, self).__init__()

        # Number of hidden dimensions
        self.hidden_dim = hidden_dim

        # Number of hidden layers
        self.layer_dim = layer_dim

        self.sigma = nn.Sigmoid()

        # RNN
        self.lstm = nn.LSTM(input_dim, hidden_dim, layer_dim,batch_first=True)

        # Readout layer
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        # Initialize hidden state with zeros
        h0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).to(device)
        c0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).to(device)

        inp = self.sigma(x)
        out, (hn, cn) = self.lstm(inp, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# # Plot the predictions

# %%
def getPredictions(model):
    # Ensure the model is in evaluation mode
    model.eval()

    # Prepare data for prediction
    entire_loader = DataLoader(TimeSeriesDataset(sequences, targets), batch_size, shuffle=False)

    # Generate predictions
    predictions = []

    with torch.no_grad():
        for x, _ in entire_loader:
            x = x.to(device)
            pred = model(x)
            predictions.append(pred.cpu().numpy())

    predictions = np.concatenate(predictions)
    
    return predictions

# %%
import matplotlib.pyplot as plt

def getPredPlot(model):
    predictions = getPredictions(model)
    # Convert predictions to a DataFrame
    pred_df = pd.DataFrame(predictions, columns=['open', 'close', 'high', 'low', 'volume'])

    # Align the index with the original data
    pred_df.index = df_norm.index[seq_length:]

    print(pred_df.head(5))
    print(df_norm.head(5))

    # Create a DataFrame for plotting
    plot_df = df_norm[seq_length:][['open', 'close', 'high', 'low']].copy()
    plot_df['predicted_close'] = pred_df['close'].copy()

    print(plot_df.head(5))

    # Plot the actual vs predicted close prices using matplotlib
    plt.figure(figsize=(14, 7))
    plt.plot(plot_df.index, plot_df['close'], label='Actual Close', color='blue')
    plt.plot(plot_df.index, plot_df['predicted_close'], label='Predicted Close', color='red', linestyle='--')
    plt.title('Actual vs Predicted Close Prices')
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %% [markdown]
# # Train the model

# %%
import math
# from torchsummary import summary

hidden_dim = 32
layer_dim = 8
model = LSTMModel(input_dim=5, hidden_dim=hidden_dim, layer_dim=layer_dim, output_dim=5).to(device)

# summary(model,(seq_length,5))

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

epochs = 3

for epoch in range(epochs):
    model.train()
    for i, (x, y) in enumerate(train_loader):
        x = x.to(device)
        y = y.to(device)
        
        optimizer.zero_grad()
        
        y_pred = model(x)
        loss = criterion(y_pred, y)
        
        loss.backward()
        optimizer.step()

        # Print status every 2000 iterations
        if (i + 1) % math.floor(len(train_loader)/30) == 0:
            print(f'Epoch [{epoch+1}/{epochs}], Iteration [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}')

            if (i+1) % (math.floor(len(train_loader)/30) * 3) == 0:
                # Evaluate on test data
                model.eval()  # Set the model to evaluation mode
                test_loss = 0.0
                test_acc = 0.0  # To accumulate accuracy scores
                total_samples = 0     # To keep track of total samples
                
                with torch.no_grad():  # Disable gradient calculation
                    for x_test, y_test in test_loader:
                        x_test = x_test.to(device)
                        y_test = y_test.to(device)

                        y_test_pred = model(x_test)
                        test_loss += criterion(y_test_pred, y_test).item()

                        if (i+1) % (math.floor(len(train_loader)/30) * 6) == 0:
                            x_test = x_test.cpu().numpy()
    
                            # Assuming the last feature in x_test is 'close'
                            # Adjust the feature index accordingly
                            prev_np = x_test[:, -1, 1]  # Shape: (batch_size,)
    
                            pred_np = y_test_pred.squeeze().cpu().numpy()[:, 1]
                            actual_np = y_test.cpu().numpy()[:,1]
                            
                            # Initialize accuracy for this batch
                            batch_accuracy = 0.0
    
                            for pred, actual, prev in zip(pred_np, actual_np, prev_np):
        
                                # if (actual > prev and pred > prev) or (actual < prev and pred < prev) or (actual == prev and pred == prev):
                                #     batch_accuracy += 1.0
                                # elif (actual != prev and pred == prev) or (actual == prev and pred != prev):
                                #     batch_accuracy += 0.5
                                
                                if (actual > prev and pred > prev) or (actual <= prev and pred <= prev):
                                    batch_accuracy += 1.0
                                else:
                                    batch_accuracy += 0.0
                                
                                total_samples += 1
                                
                            test_acc += batch_accuracy

                test_loss /= len(test_loader)  # Average test loss
                print(f'Test Loss: {test_loss:.4f}')
                if (test_acc != 0):
                    test_acc /=  (total_samples / 100)  # Percentage
                    print(f'Test Accuracy: {test_acc:.2f}%')
                
                model.train()  # Set the model back to training mode
    getPredPlot(model)
# Out:
# Epoch [1/3], Iteration [2305/69163], Loss: 0.2899
# Epoch [1/3], Iteration [4610/69163], Loss: 0.2329
# Epoch [1/3], Iteration [6915/69163], Loss: 0.1693
# Test Loss: 0.1521
# Epoch [1/3], Iteration [9220/69163], Loss: 0.1984
# Epoch [1/3], Iteration [11525/69163], Loss: 0.1780
# Epoch [1/3], Iteration [13830/69163], Loss: 0.1451
# Test Loss: 0.1237
# Test Accuracy: 54.59%
# Epoch [1/3], Iteration [16135/69163], Loss: 0.2662
# Epoch [1/3], Iteration [18440/69163], Loss: 0.1888
# Epoch [1/3], Iteration [20745/69163], Loss: 0.1926
# Test Loss: 0.1411
# Epoch [1/3], Iteration [23050/69163], Loss: 0.0926
# Epoch [1/3], Iteration [25355/69163], Loss: 0.0688
# Epoch [1/3], Iteration [27660/69163], Loss: 0.1299
# Test Loss: 0.0479
# Test Accuracy: 43.22%
# Epoch [1/3], Iteration [29965/69163], Loss: 0.1584
# Epoch [1/3], Iteration [32270/69163], Loss: 0.1008
# Epoch [1/3], Iteration [34575/69163], Loss: 0.1203
# Test Loss: 0.0476
# Epoch [1/3], Iteration [36880/69163], Loss: 0.0863
# Epoch [1/3], Iteration [39185/69163], Loss: 0.0883
# Epoch [1/3], Iteration [41490/69163], Loss: 0.0717
# Test Loss: 0.0485
# Test Accuracy: 46.65%
# Epoch [1/3], Iteration [43795/69163], Loss: 0.0819
# Epoch [1/3], Iteration [46100/69163], Loss: 0.1179
# Epoch [1/3], Iteration [48405/69163], Loss: 0.0907
# Test Loss: 0.0484
# Epoch [1/3], Iteration [50710/69163], Loss: 0.1129
# Epoch [1/3], Iteration [53015/69163], Loss: 0.0701
# Epoch [1/3], Iteration [55320/69163], Loss: 0.0978
# Test Loss: 0.0454
# Test Accuracy: 46.38%
# Epoch [1/3], Iteration [57625/69163], Loss: 0.1102
# Epoch [1/3], Iteration [59930/69163], Loss: 0.0879
# Epoch [1/3], Iteration [62235/69163], Loss: 0.1435
# Test Loss: 0.0458
# Epoch [1/3], Iteration [64540/69163], Loss: 0.0990
# Epoch [1/3], Iteration [66845/69163], Loss: 0.1054
# Epoch [1/3], Iteration [69150/69163], Loss: 0.1035
# Test Loss: 0.0466
# Test Accuracy: 43.82%
#                          open     close      high       low    volume
# 2013-04-01 01:11:00 -1.840394 -1.840645 -1.840664 -1.841457 -0.550925
# 2013-04-01 01:12:00 -1.840154 -1.841629 -1.840326 -1.842196 -0.339746
# 2013-04-01 01:13:00 -1.844079 -1.845908 -1.843785 -1.845545 -0.154181
# 2013-04-01 01:14:00 -1.846373 -1.848136 -1.846434 -1.848245 -0.249896
# 2013-04-01 01:15:00 -1.848346 -1.849180 -1.848533 -1.849656 -0.423108
#                          open     close      high       low    volume
# 2013-04-01 00:07:00 -1.871413 -1.871139 -1.871313 -1.871239  2.502149
# 2013-04-01 00:08:00 -1.835350 -1.835353 -1.835527 -1.835175  2.502149
# 2013-04-01 00:09:00 -1.871136 -1.871139 -1.871313 -1.870962  1.758977
# 2013-04-01 00:10:00 -1.871136 -1.871139 -1.871313 -1.870962 -0.875289
# 2013-04-01 00:11:00 -1.870860 -1.870200 -1.870374 -1.870686  1.386391
#                          open     close      high       low  predicted_close
# 2013-04-01 01:11:00 -1.870142 -1.870697 -1.870319 -1.870520        -1.840645
# 2013-04-01 01:12:00 -1.870142 -1.870101 -1.870275 -1.871515        -1.841629
# 2013-04-01 01:13:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.845908
# 2013-04-01 01:14:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.848136
# 2013-04-01 01:15:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.849180
# Epoch [2/3], Iteration [2305/69163], Loss: 0.0596
# Epoch [2/3], Iteration [4610/69163], Loss: 0.0815
# Epoch [2/3], Iteration [6915/69163], Loss: 0.1171
# Test Loss: 0.0456
# Epoch [2/3], Iteration [9220/69163], Loss: 0.1336
# Epoch [2/3], Iteration [11525/69163], Loss: 0.1777
# Epoch [2/3], Iteration [13830/69163], Loss: 0.1096
# Test Loss: 0.0454
# Test Accuracy: 47.52%
# Epoch [2/3], Iteration [16135/69163], Loss: 0.0938
# Epoch [2/3], Iteration [18440/69163], Loss: 0.0796
# Epoch [2/3], Iteration [20745/69163], Loss: 0.1643
# Test Loss: 0.0447
# Epoch [2/3], Iteration [23050/69163], Loss: 0.1917
# Epoch [2/3], Iteration [25355/69163], Loss: 0.1214
# Epoch [2/3], Iteration [27660/69163], Loss: 0.0924
# Test Loss: 0.0472
# Test Accuracy: 43.06%
# Epoch [2/3], Iteration [29965/69163], Loss: 0.0958
# Epoch [2/3], Iteration [32270/69163], Loss: 0.1124
# Epoch [2/3], Iteration [34575/69163], Loss: 0.0930
# Test Loss: 0.0445
# Epoch [2/3], Iteration [36880/69163], Loss: 0.1249
# Epoch [2/3], Iteration [39185/69163], Loss: 0.1061
# Epoch [2/3], Iteration [41490/69163], Loss: 0.0869
# Test Loss: 0.0444
# Test Accuracy: 53.96%
# Epoch [2/3], Iteration [43795/69163], Loss: 0.1393
# Epoch [2/3], Iteration [46100/69163], Loss: 0.0896
# Epoch [2/3], Iteration [48405/69163], Loss: 0.0952
# Test Loss: 0.0453
# Epoch [2/3], Iteration [50710/69163], Loss: 0.0731
# Epoch [2/3], Iteration [53015/69163], Loss: 0.1376
# Epoch [2/3], Iteration [55320/69163], Loss: 0.1241
# Test Loss: 0.0454
# Test Accuracy: 46.56%
# Epoch [2/3], Iteration [57625/69163], Loss: 0.0990
# Epoch [2/3], Iteration [59930/69163], Loss: 0.0998
# Epoch [2/3], Iteration [62235/69163], Loss: 0.0544
# Test Loss: 0.0441
# Epoch [2/3], Iteration [64540/69163], Loss: 0.1645
# Epoch [2/3], Iteration [66845/69163], Loss: 0.0939
# Epoch [2/3], Iteration [69150/69163], Loss: 0.1378
# Test Loss: 0.0446
# Test Accuracy: 47.03%
#                          open     close      high       low    volume
# 2013-04-01 01:11:00 -1.846238 -1.846244 -1.846370 -1.846166 -0.709620
# 2013-04-01 01:12:00 -1.844468 -1.844655 -1.844639 -1.844744 -0.428755
# 2013-04-01 01:13:00 -1.843887 -1.843960 -1.843929 -1.843991 -0.220957
# 2013-04-01 01:14:00 -1.838280 -1.838378 -1.838329 -1.838452 -0.326302
# 2013-04-01 01:15:00 -1.834909 -1.834892 -1.834949 -1.834859 -0.557630
#                          open     close      high       low    volume
# 2013-04-01 00:07:00 -1.871413 -1.871139 -1.871313 -1.871239  2.502149
# 2013-04-01 00:08:00 -1.835350 -1.835353 -1.835527 -1.835175  2.502149
# 2013-04-01 00:09:00 -1.871136 -1.871139 -1.871313 -1.870962  1.758977
# 2013-04-01 00:10:00 -1.871136 -1.871139 -1.871313 -1.870962 -0.875289
# 2013-04-01 00:11:00 -1.870860 -1.870200 -1.870374 -1.870686  1.386391
#                          open     close      high       low  predicted_close
# 2013-04-01 01:11:00 -1.870142 -1.870697 -1.870319 -1.870520        -1.846244
# 2013-04-01 01:12:00 -1.870142 -1.870101 -1.870275 -1.871515        -1.844655
# 2013-04-01 01:13:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.843960
# 2013-04-01 01:14:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.838378
# 2013-04-01 01:15:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.834892
# Epoch [3/3], Iteration [2305/69163], Loss: 0.0964
# Epoch [3/3], Iteration [4610/69163], Loss: 0.0860
# Epoch [3/3], Iteration [6915/69163], Loss: 0.1138
# Test Loss: 0.0449
# Epoch [3/3], Iteration [9220/69163], Loss: 0.0989
# Epoch [3/3], Iteration [11525/69163], Loss: 0.0873
# Epoch [3/3], Iteration [13830/69163], Loss: 0.1101
# Test Loss: 0.0448
# Test Accuracy: 57.00%
# Epoch [3/3], Iteration [16135/69163], Loss: 0.0686
# Epoch [3/3], Iteration [18440/69163], Loss: 0.0783
# Epoch [3/3], Iteration [20745/69163], Loss: 0.1208
# Test Loss: 0.0445
# Epoch [3/3], Iteration [23050/69163], Loss: 0.0826
# Epoch [3/3], Iteration [25355/69163], Loss: 0.1510
# Epoch [3/3], Iteration [27660/69163], Loss: 0.0786
# Test Loss: 0.0443
# Test Accuracy: 45.27%
# Epoch [3/3], Iteration [29965/69163], Loss: 0.1324
# Epoch [3/3], Iteration [32270/69163], Loss: 0.0805
# Epoch [3/3], Iteration [34575/69163], Loss: 0.0979
# Test Loss: 0.0458
# Epoch [3/3], Iteration [36880/69163], Loss: 0.1074
# Epoch [3/3], Iteration [39185/69163], Loss: 0.1738
# Epoch [3/3], Iteration [41490/69163], Loss: 0.1097
# Test Loss: 0.0445
# Test Accuracy: 51.52%
# Epoch [3/3], Iteration [43795/69163], Loss: 0.0979
# Epoch [3/3], Iteration [46100/69163], Loss: 0.1082
# Epoch [3/3], Iteration [48405/69163], Loss: 0.0822
# Test Loss: 0.0443
# Epoch [3/3], Iteration [50710/69163], Loss: 0.0788
# Epoch [3/3], Iteration [53015/69163], Loss: 0.1154
# Epoch [3/3], Iteration [55320/69163], Loss: 0.1139
# Test Loss: 0.0455
# Test Accuracy: 57.20%
# Epoch [3/3], Iteration [57625/69163], Loss: 0.0973
# Epoch [3/3], Iteration [59930/69163], Loss: 0.0939
# Epoch [3/3], Iteration [62235/69163], Loss: 0.0874
# Test Loss: 0.0458
# Epoch [3/3], Iteration [64540/69163], Loss: 0.1167
# Epoch [3/3], Iteration [66845/69163], Loss: 0.1203
# Epoch [3/3], Iteration [69150/69163], Loss: 0.1050
# Test Loss: 0.0454
# Test Accuracy: 49.61%
#                          open     close      high       low    volume
# 2013-04-01 01:11:00 -1.875309 -1.875171 -1.875309 -1.875174 -0.637628
# 2013-04-01 01:12:00 -1.870146 -1.870015 -1.870129 -1.870049 -0.392018
# 2013-04-01 01:13:00 -1.879189 -1.879076 -1.879099 -1.879170 -0.199477
# 2013-04-01 01:14:00 -1.872655 -1.872521 -1.872565 -1.872604 -0.305149
# 2013-04-01 01:15:00 -1.873118 -1.872976 -1.873061 -1.873015 -0.517210
#                          open     close      high       low    volume
# 2013-04-01 00:07:00 -1.871413 -1.871139 -1.871313 -1.871239  2.502149
# 2013-04-01 00:08:00 -1.835350 -1.835353 -1.835527 -1.835175  2.502149
# 2013-04-01 00:09:00 -1.871136 -1.871139 -1.871313 -1.870962  1.758977
# 2013-04-01 00:10:00 -1.871136 -1.871139 -1.871313 -1.870962 -0.875289
# 2013-04-01 00:11:00 -1.870860 -1.870200 -1.870374 -1.870686  1.386391
#                          open     close      high       low  predicted_close
# 2013-04-01 01:11:00 -1.870142 -1.870697 -1.870319 -1.870520        -1.875171
# 2013-04-01 01:12:00 -1.870142 -1.870101 -1.870275 -1.871515        -1.870015
# 2013-04-01 01:13:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.879076
# 2013-04-01 01:14:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.872521
# 2013-04-01 01:15:00 -1.870098 -1.870101 -1.870275 -1.869924        -1.872976

# %%
# torch.cuda.memory._dump_snapshot("snapshot.pickle")

# %%
model.eval()
torch.save({"model_state_dict": model.cpu().state_dict()}, "models/lstm.model")
